# %% [markdown]
# <a href="https://colab.research.google.com/github/gobi2001-2006/GEN-AI/blob/main/GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, Reshape
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import mnist
from tensorflow.keras.optimizers import Adam

# Load the MNIST dataset
(x_train, _), (_, _) = mnist.load_data()
x_train = x_train / 127.5 - 1.0  # Normalize to [-1, 1]
x_train = np.expand_dims(x_train, axis=-1)  # Add channel dimension

# Hyperparameters
latent_dim = 100  # Latent space dimensionality
batch_size = 128
epochs = 500  # Number of epochs
sample_interval = 100  # Interval for saving generated images

# Create the generator model
def build_generator():
    model = Sequential()
    model.add(Dense(256, input_dim=latent_dim))
    model.add(tf.keras.layers.LeakyReLU(0.2))
    model.add(Dense(512))
    model.add(tf.keras.layers.LeakyReLU(0.2))
    model.add(Dense(1024))
    model.add(tf.keras.layers.LeakyReLU(0.2))
    model.add(Dense(28 * 28 * 1, activation='tanh'))  # MNIST image shape (28x28x1)
    model.add(Reshape((28, 28, 1)))  # Reshape into 28x28 image
    return model

# Create the discriminator model
def build_discriminator():
    model = Sequential()
    model.add(Flatten(input_shape=(28, 28, 1)))  # Flatten the image into a vector
    model.add(Dense(1024))
    model.add(tf.keras.layers.LeakyReLU(0.2))
    model.add(Dense(512))
    model.add(tf.keras.layers.LeakyReLU(0.2))
    model.add(Dense(256))
    model.add(tf.keras.layers.LeakyReLU(0.2))
    model.add(Dense(1, activation='sigmoid'))  # Output probability of being real
    return model

# Create the GAN model
def build_gan(generator, discriminator):
    discriminator.trainable = False  # Freeze discriminator when training GAN
    model = Sequential()
    model.add(generator)
    model.add(discriminator)
    return model

# Compile the models
discriminator = build_discriminator()
discriminator.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0002, beta_1=0.5), metrics=['accuracy'])

generator = build_generator()

# GAN model combines generator and discriminator
gan = build_gan(generator, discriminator)
gan.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0002, beta_1=0.5))

# Function to train the GAN
def train_gan(epochs, batch_size, sample_interval):
    half_batch = batch_size // 2

    for epoch in range(epochs):

        # Train discriminator
        idx = np.random.randint(0, x_train.shape[0], half_batch)
        real_images = x_train[idx]

        noise = np.random.normal(0, 1, (half_batch, latent_dim))
        fake_images = generator.predict(noise)

        real_labels = np.ones((half_batch, 1))
        fake_labels = np.zeros((half_batch, 1))

        d_loss_real = discriminator.train_on_batch(real_images, real_labels)
        d_loss_fake = discriminator.train_on_batch(fake_images, fake_labels)
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

        # Train generator
        noise = np.random.normal(0, 1, (batch_size, latent_dim))
        valid_labels = np.ones((batch_size, 1))  # We want the generator to fool the discriminator

        g_loss = gan.train_on_batch(noise, valid_labels)

        # Print the progress
        if epoch % sample_interval == 0:
            print(f"{epoch} [D loss: {d_loss[0]} | D accuracy: {100 * d_loss[1]}] [G loss: {g_loss}]")

            # Save generated image samples
            if epoch % (sample_interval * 10) == 0:
                sample_images(epoch)

# Function to save generated images
def sample_images(epoch, latent_dim=100):
    # Ensure the output directory exists
    os.makedirs('gan_images', exist_ok=True)  # This line creates the directory if it doesn't exist

    noise = np.random.normal(0, 1, (16, latent_dim))
    gen_imgs = generator.predict(noise)
    gen_imgs = 0.5 * gen_imgs + 0.5  # Rescale images from [-1, 1] to [0, 1]

    fig, axs = plt.subplots(4, 4, figsize=(4, 4))
    cnt = 0
    for i in range(4):
        for j in range(4):
            axs[i, j].imshow(gen_imgs[cnt, :, :, 0], cmap='gray')
            axs[i, j].axis('off')
            cnt += 1
    fig.savefig(f"gan_images/gan_{epoch}.png")
    plt.close()

# Start the training process
train_gan(epochs=500, batch_size=batch_size, sample_interval=100)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer._make_function.<locals>.one_step_on_data at 0x7b8b506c6840> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Reshape, Flatten, BatchNormalization, LeakyReLU
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.optimizers import Adam
import os

# Load and preprocess the CIFAR-10 data
(x_train, _), (_, _) = cifar10.load_data()
x_train = (x_train - 127.5) / 127.5  # Normalize to [-1, 1]
x_train = x_train.astype(np.float32)

# Hyperparameters
latent_dim = 100  # Latent space dimensionality
batch_size = 128
epochs = 500  # Number of epochs
sample_interval = 100  # Interval for saving generated images

# Generator Model
def build_generator():
    model = Sequential()
    model.add(Dense(256, input_dim=latent_dim))
    model.add(LeakyReLU(0.2))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Dense(512))
    model.add(LeakyReLU(0.2))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Dense(1024))
    model.add(LeakyReLU(0.2))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Dense(32 * 32 * 3, activation='tanh'))  # CIFAR-10 image shape (32x32x3)
    model.add(Reshape((32, 32, 3)))  # Reshape into 32x32 image with 3 channels (RGB)
    return model

# Discriminator Model
def build_discriminator():
    model = Sequential()
    model.add(Flatten(input_shape=(32, 32, 3)))  # Flatten the image into a vector
    model.add(Dense(512))
    model.add(LeakyReLU(0.2))
    model.add(Dense(256))
    model.add(LeakyReLU(0.2))
    model.add(Dense(1, activation='sigmoid'))  # Output probability of being real
    return model

# Combine Generator and Discriminator to form the GAN
def build_gan(generator, discriminator):
    discriminator.trainable = False  # Freeze discriminator when training GAN
    model = Sequential()
    model.add(generator)
    model.add(discriminator)
    return model

# Compile the models
discriminator = build_discriminator()
discriminator.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0002, beta_1=0.5), metrics=['accuracy'])

generator = build_generator()

# GAN model combines generator and discriminator
gan = build_gan(generator, discriminator)
gan.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0002, beta_1=0.5))

# Function to train the GAN
def train_gan(epochs, batch_size, sample_interval):
    half_batch = batch_size // 2

    # Create directory to save generated images
    os.makedirs('gan_images', exist_ok=True)

    for epoch in range(epochs):
        # Train discriminator
        idx = np.random.randint(0, x_train.shape[0], half_batch)
        real_images = x_train[idx]

        noise = np.random.normal(0, 1, (half_batch, latent_dim))
        fake_images = generator.predict(noise)

        real_labels = np.ones((half_batch, 1))
        fake_labels = np.zeros((half_batch, 1))

        d_loss_real = discriminator.train_on_batch(real_images, real_labels)
        d_loss_fake = discriminator.train_on_batch(fake_images, fake_labels)
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

        # Train generator
        noise = np.random.normal(0, 1, (batch_size, latent_dim))
        valid_labels = np.ones((batch_size, 1))  # We want the generator to fool the discriminator

        g_loss = gan.train_on_batch(noise, valid_labels)

        # Print the progress
        if epoch % sample_interval == 0:
            print(f"{epoch} [D loss: {d_loss[0]} | D accuracy: {100 * d_loss[1]}] [G loss: {g_loss}]")

            # Save generated image samples
            if epoch % (sample_interval * 10) == 0:
                save_images(epoch)

# Function to save generated images
def save_images(epoch, latent_dim=100):
    noise = np.random.normal(0, 1, (16, latent_dim))
    gen_imgs = generator.predict(noise)
    gen_imgs = 0.5 * gen_imgs + 0.5  # Rescale images from [-1, 1] to [0, 1]

    fig, axs = plt.subplots(4, 4, figsize=(4, 4))
    cnt = 0
    for i in range(4):
        for j in range(4):
            axs[i, j].imshow(gen_imgs[cnt], cmap='gray')
            axs[i, j].axis('off')
            cnt += 1
    fig.savefig(f"gan_images/gan_{epoch}.png")
    plt.close()

# Start the training process
train_gan(epochs=500, batch_size=batch_size, sample_interval=100)
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 0 [D loss: 0.7986094951629639 | D accuracy: 31.640625] [G loss: 0.8752182722091675]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Reshape, Flatten, BatchNormalization, LeakyReLU, Dropout
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.optimizers import Adam
import os

# Load and preprocess CIFAR-10 data
(x_train, _), (_, _) = cifar10.load_data()
x_train = (x_train - 127.5) / 127.5  # Normalize to [-1, 1]
x_train = x_train.astype(np.float32)

# Hyperparameters
latent_dim = 100
batch_size = 128
epochs = 500
sample_interval = 100

# Generator Model
def build_generator():
    model = Sequential()
    model.add(Dense(256, input_dim=latent_dim))
    model.add(LeakyReLU(0.2))
    model.add(BatchNormalization(momentum=0.8))

    model.add(Dense(512))
    model.add(LeakyReLU(0.2))
    model.add(BatchNormalization(momentum=0.8))

    model.add(Dense(1024))
    model.add(LeakyReLU(0.2))
    model.add(BatchNormalization(momentum=0.8))

    model.add(Dense(32 * 32 * 3, activation='sigmoid'))  # Use sigmoid instead of tanh
    model.add(Reshape((32, 32, 3)))

    return model

# Discriminator Model
def build_discriminator():
    model = Sequential()
    model.add(Flatten(input_shape=(32, 32, 3)))
    model.add(Dense(512))
    model.add(LeakyReLU(0.2))
    model.add(Dropout(0.3))  # Add dropout for stability

    model.add(Dense(256))
    model.add(LeakyReLU(0.2))
    model.add(Dropout(0.3))

    model.add(Dense(1, activation='sigmoid'))
    return model

# Combine Generator and Discriminator
def build_gan(generator, discriminator):
    discriminator.trainable = False
    model = Sequential()
    model.add(generator)
    model.add(discriminator)
    return model

# Compile the models
discriminator = build_discriminator()
discriminator.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0001, beta_1=0.5), metrics=['accuracy'])

generator = build_generator()

gan = build_gan(generator, discriminator)
gan.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0001, beta_1=0.5))

# Training Function
def train_gan(epochs, batch_size, sample_interval):
    half_batch = batch_size // 2

    os.makedirs('gan_images', exist_ok=True)

    for epoch in range(epochs):
        # Train Discriminator
        idx = np.random.randint(0, x_train.shape[0], half_batch)
        real_images = x_train[idx]

        noise = np.random.normal(0, 1, (half_batch, latent_dim))
        fake_images = generator.predict(noise)

        real_labels = np.ones((half_batch, 1)) * 0.9  # Use label smoothing
        fake_labels = np.zeros((half_batch, 1)) + 0.1

        d_loss_real = discriminator.train_on_batch(real_images, real_labels)
        d_loss_fake = discriminator.train_on_batch(fake_images, fake_labels)
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

        # Train Generator
        noise = np.random.normal(0, 1, (batch_size, latent_dim))
        valid_labels = np.ones((batch_size, 1))

        g_loss = gan.train_on_batch(noise, valid_labels)

        # Print the progress
        if epoch % sample_interval == 0:
            print(f"{epoch} [D loss: {d_loss[0]} | D accuracy: {100 * d_loss[1]:.2f}%] [G loss: {g_loss}]")
            save_images(epoch)

# Function to Save Generated Images
def save_images(epoch):
    noise = np.random.normal(0, 1, (16, latent_dim))
    gen_imgs = generator.predict(noise)
    gen_imgs = np.clip(gen_imgs, 0, 1)  # Ensure values are in [0,1]

    fig, axs = plt.subplots(4, 4, figsize=(4, 4))
    cnt = 0
    for i in range(4):
        for j in range(4):
            axs[i, j].imshow(gen_imgs[cnt])  # Removed cmap='gray' for color images
            axs[i, j].axis('off')
            cnt += 1
    fig.savefig(f"gan_images/gan_{epoch}.png")
    plt.close()

# Start Training
train_gan(epochs=500, batch_size=batch_size, sample_interval=100)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 0 [D loss: 0.7694854736328125 | D accuracy: 0.00%] [G loss: 0.7217502593994141]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# ...

# %%
pip install torch torchvision transformers pillow huggingface_hub

# %%
# !pip install diffusers torch transformers gradio

from diffusers import StableDiffusionPipeline
import torch
import gradio as gr

# Load model
pipe = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4")
pipe.to("cuda")

# Function to generate image
def generate_image(prompt):
    image = pipe(prompt).images[0]
    return image

# Launch public web app
gr.Interface(fn=generate_image, inputs="text", outputs="image").launch(share=True)
# Out:
# ...
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://b12450941a564eac36.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://b12450941a564eac36.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
