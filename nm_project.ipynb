# %% [markdown]
# <a href="https://colab.research.google.com/github/gobi2001-2006/GEN-AI/blob/main/nm_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers gtts -q

# %%
from gtts import gTTS
from IPython.display import Audio

# %%
import ipywidgets as widgets

# %%
import ipywidgets as widgets
from IPython.display import display

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model_name = "google/flan-t5-large"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# ...

# %%
def generate_recipe(ingredients):
    prompt = f"Create a recipe and a cooking video script using these ingredients: {ingredients}"
    inputs = tokenizer(prompt, return_tensors="pt", max_length=256, truncation=True)
    outputs = model.generate(**inputs, max_length=512)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# %%
ingredient_input = widgets.Textarea(
    value='eggs, onion, tomato',
    placeholder='Enter ingredients, e.g. rice, beans, spinach',
    description='Ingredients:',
    layout=widgets.Layout(width='80%', height='80px')
)

generate_button = widgets.Button(description="Generate Recipe", button_style='success')
output_box = widgets.Output()

# %%
def on_button_click(b):
    with output_box:
        output_box.clear_output()
        ingredients = ingredient_input.value
        result = generate_recipe(ingredients)
        print("📋 Generated Recipe and Video Script:\n")
        print(result)

        # Convert to audio
        tts = gTTS(result)
        tts.save("recipe.mp3")
        display(Audio("recipe.mp3"))

# %%
generate_button.on_click(on_button_click)

# %%
display(ingredient_input, generate_button, output_box)
# Out:
# Textarea(value='eggs, onion, tomato', description='Ingredients:', layout=Layout(height='80px', width='80%'), p…
# Button(button_style='success', description='Generate Recipe', style=ButtonStyle())
# Output()

# %%
# Import necessary libraries
import ipywidgets as widgets
from IPython.display import display, Audio
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from gtts import gTTS

# Load the Hugging Face model and tokenizer
model_name = "google/flan-t5-large"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# Define the recipe generation function
def generate_recipe(ingredients):
    prompt = f"Create a detailed recipe with cooking instructions and a video script using these ingredients: {ingredients}. Include step-by-step instructions, preparation time, and a cooking video script."

    inputs = tokenizer(prompt, return_tensors="pt", max_length=256, truncation=True)
    outputs = model.generate(**inputs, max_length=512)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# Define the UI widgets for user input
ingredient_input = widgets.Textarea(
      # Default value
    placeholder='Enter ingredients, e.g. rice, beans, spinach',  # Placeholder text
    description='Ingredients:',
    layout=widgets.Layout(width='80%', height='80px')  # Textarea style
)

generate_button = widgets.Button(description="Generate Recipe", button_style='success')  # Button to generate recipe
output_box = widgets.Output()  # Box to display the recipe output

# Button click function
def on_button_click(b):
    with output_box:
        output_box.clear_output()  # Clear previous outputs
        ingredients = ingredient_input.value  # Get user input ingredients
        result = generate_recipe(ingredients)  # Generate recipe
        print("📋 Generated Recipe and Video Script:\n")
        print(result)  # Print the recipe

        # Convert the result to speech (TTS)
        tts = gTTS(result)
        tts.save("recipe.mp3")
        display(Audio("recipe.mp3"))  # Play the generated audio

# Link the button to the click function
generate_button.on_click(on_button_click)

# Display the UI
display(ingredient_input, generate_button, output_box)
# Out:
# Textarea(value='', description='Ingredients:', layout=Layout(height='80px', width='80%'), placeholder='Enter i…
# Button(button_style='success', description='Generate Recipe', style=ButtonStyle())
# Output()
